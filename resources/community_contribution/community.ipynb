# %% [markdown]
# # 🌟 Community Contributions
#
# Thank you for considering contributing your work to the repo!
#
# Please add your code (modules or notebooks) to this directory and send me a Pull Request (PR), per the instructions.
#
# I'd love to share your progress with other students so everyone can benefit from your projects.
#
# ### 📂 How to Add Your Work
#
# You can contribute in one of two ways:
#
# 1. **Create your own Folder:** Feel free to create a folder named after yourself (e.g., `John_Doe_Projects/`).
# 2. **Add a Single File:** If you are adding a specific assignment file, please use the naming convention below to keep things organized.
#
# ### 📝 Naming Convention
#
# If adding individual files, please use the following format:
#
# `{day}_{Topic_name}_{Your_name}.ipynb` or `.py`
#
# **Example:**
#
# > `04_Operators_and_Boolean_Logic_John.ipynb`
