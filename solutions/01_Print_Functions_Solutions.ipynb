# %%
# 1. Print the total cost (Add pizza and drinks)
print("Total Bill:")
print(40 + 15)

# 2. Print the split (Total / 4)
print("Each person pays:")
print((40 + 15) / 4)
# Out:
# Total Bill:
# 55
# Each person pays:
# 13.75
