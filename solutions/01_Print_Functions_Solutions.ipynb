# %%
# Level 1: The Ritual

print("Hello World")
# Out:
# Hello World

# %%
# Level 2: The Introduction

print("My name is Stark")
print("I live in USA")
print("I love Engineering")
# Out:
# My name is Stark
# I live in USA
# I love Engineering

# %%
# Level 3: The Architect

print("  ^  ")
print(" / \\ ") # Note: You might need double backslash \\ to print one backslash!
print("/   \\") # Note: You might need double backslash \\ to print one backslash!
# Out:
#   ^
#  / \
# /   \

# %%
# Level 4: The Debugger

print("Hello World")      # Missing closing parenthesis )
print("I love Python")    # Missing parentheses ()
print("My name is Tony")  # Missing quotes ""
# Out:
# Hello World
# I love Python
# My name is Tony

# %%
# Level 5: The Business Card
print("-------------------------")
print(" Name: Iron Man")
print(" Role: Python Student")
print(" 2026 Goals: Save World")
print("-------------------------")
# Out:
# -------------------------
#  Name: Iron Man
#  Role: Python Student
#  2026 Goals: Save World
# -------------------------
