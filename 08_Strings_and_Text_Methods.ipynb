# %% [markdown]
# # Day 08: Text Surgery (String Slicing & Methods) 🔪
#
# ## 👋 Welcome Back!
# You think you know text? You've been printing "Hello World" since Day 1.
# But did you know that in Python, a String is actually a **Sequence**?
#
# It's not just one object; it's a chain of characters tied together.
# Today, we learn how to cut that chain, modify it, and analyze it. This is a superpower for **Data Science** (cleaning messy data).
#
# ---
#
# ## 🔍 Topic 1: Indexing (The Address System)
# Every character in a string has a specific address (Index).
# **Crucial Rule:** Computers start counting at **0**.
#
# | P | y | t | h | o | n |
# |---|---|---|---|---|---|
# | 0 | 1 | 2 | 3 | 4 | 5 |
#
# You can grab a specific character using square brackets `[]`.

# %%
text = "Python"

print(text[0])  # 'P' (The first letter)
print(text[1])  # 'y'

# 🧠 The Negative Index (The Cool Trick)
# -1 means "The last item". -2 means "Second to last".
print(text[-1]) # 'n'

# %% [markdown]
# ---
# ## 🍰 Topic 2: Slicing (The Cake Cutter)
# What if you want a chunk of text, not just one letter?
# We use slicing: `[start : stop : step]`
#
# * **Start:** Where to begin (Inclusive).
# * **Stop:** Where to end (**Exclusive** - stops BEFORE this index).
# * **Step:** Jump size (Optional).

# %%
text = "I love Python Programming"

# 1. Basic Slice (Get "Python")
# 'P' is at index 7. 'n' is at 12. So we stop at 13.
print(text[7:13]) 

# 2. Start from beginning to...
print(text[:6])   # "I love" (0 to 6)

# 3. From somewhere to the end...
print(text[7:])   # "Python Programming" (7 to end)

# 4. The Reverser (Interview Trick)
# Step -1 means "Walk backwards"
print(text[::-1]) # gnimmargorP nohtyP evol I

# %% [markdown]
# #### The "Off By One" Slicing Error
#
# **Concept**: [Start : Stop]
#
# **Confusion**: Students expect [0:3] to give indices 0, 1, 2, 3 (4 items). It gives 0, 1, 2 (3 items).
#
# **Analogy**: "The Stop index is a wall. You stop when you hit the wall, you don't include the wall."

# %% [markdown]
# ---
# ## 🛠️ Topic 3: String Methods (The Toolkit)
# Strings come with built-in tools (Methods) to clean themselves up.
#
# | Method | What it does |
# | :--- | :--- |
# | `.upper()` | Converts to ALL CAPS |
# | `.lower()` | Converts to lowercase |
# | `.strip()` | Removes annoying spaces from start/end |
# | `.replace(old, new)` | Swaps text |
# | `.find(sub)` | Finds the index of a word |
# | `.count(sub)` | Counts how many times a word appears |

# %%
messy_text = "   HeLLo WoRLd   "

print("Original:", messy_text)

# 1. Clean spaces
clean = messy_text.strip()
print("Stripped:", clean)

# 2. Fix casing
print("Lower:", clean.lower())
print("Upper:", clean.upper())

# 3. Replacement
sentence = "I hate bugs."
new_sentence = sentence.replace("hate", "love")
print(new_sentence)

# %% [markdown]
# ### 📑 Python String Methods with Examples
# All available methods. You don't need to remember these. Just know that they exists.
# > NOTE: You can use dir(str) to get this list.
#
# | Method | Description | Example |
# |--------|-------------|---------|
# | `capitalize()` | Capitalizes first char, lowercases rest | `"hello".capitalize()` → `"Hello"` |
# | `casefold()` | Lowercases aggressively for caseless matching | `"HELLO".casefold()` → `"hello"` |
# | `center(width, fillchar=' ')` | Centers string in given width | `"hi".center(6, '-')` → `"--hi--"` |
# | `count(sub[, start[, end]])` | Counts non-overlapping substring | `"banana".count("na")` → `2` |
# | `encode(encoding, errors)` | Encodes to bytes | `"hi".encode("utf-8")` → `b'hi'` |
# | `endswith(suffix)` | Checks if ends with suffix | `"test.py".endswith(".py")` → `True` |
# | `expandtabs(tabsize)` | Replaces tabs with spaces | `"a\tb".expandtabs(4)` → `"a   b"` |
# | `find(sub)` | Lowest index of substring, -1 if not found | `"hello".find("l")` → `2` |
# | `format()` | String formatting | `"{} scored {}".format("Ram", 95)` → `"Ram scored 95"` |
# | `format_map(mapping)` | Formatting with dict/map | `"{name}".format_map({"name":"Sita"})` → `"Sita"` |
# | `index(sub)` | Like find, but raises error if not found | `"hello".index("e")` → `1` |
# | `isalnum()` | True if alphanumeric | `"abc123".isalnum()` → `True` |
# | `isalpha()` | True if alphabetic and is not blank | `"abc".isalpha()` → `True` |
# | `isascii()` | True if all ASCII | `"abc".isascii()` → `True` |
# | `isdecimal()` | True if only decimals | `"123".isdecimal()` → `True` |
# | `isdigit()` | True if only digits | `"²3".isdigit()` → `True` |
# | `isidentifier()` | Valid Python identifier? | `"var1".isidentifier()` → `True` |
# | `islower()` | True if all lowercase | `"hello".islower()` → `True` |
# | `isnumeric()` | True if numeric | `"Ⅳ".isnumeric()` → `True` |
# | `isprintable()` | True if all printable | `"abc\n".isprintable()` → `False` |
# | `isspace()` | True if only whitespace | `"   ".isspace()` → `True` |
# | `istitle()` | True if titlecased | `"Hello World".istitle()` → `True` |
# | `isupper()` | True if all uppercase | `"HELLO".isupper()` → `True` |
# | `join(iterable)` | Joins iterable with string as separator | `",".join(["a","b"])` → `"a,b"` |
# | `ljust(width)` | Left-justifies with spaces | `"hi".ljust(5, ".")` → `"hi..."` |
# | `lower()` | Converts to lowercase | `"HELLO".lower()` → `"hello"` |
# | `lstrip(chars)` | Removes leading chars | `"---hi".lstrip("-")` → `"hi"` |
# | `maketrans()` | Creates translation table | `str.maketrans("abc","123")` |
# | `partition(sep)` | Splits at first sep into 3 parts | `"a=b".partition("=")` → `("a","=","b")` |
# | `removeprefix(prefix)` | Removes prefix if present | `"unhappy".removeprefix("un")` → `"happy"` |
# | `removesuffix(suffix)` | Removes suffix if present | `"file.txt".removesuffix(".txt")` → `"file"` |
# | `replace(old,new)` | Replaces substring | `"hello".replace("l","x")` → `"hexxo"` |
# | `rfind(sub)` | Highest index of substring | `"hello".rfind("l")` → `3` |
# | `rindex(sub)` | Highest index, raises error if not found | `"hello".rindex("o")` → `4` |
# | `rjust(width)` | Right-justifies string | `"hi".rjust(5,".")` → `"...hi"` |
# | `rpartition(sep)` | Splits at last sep into 3 parts | `"a=b=c".rpartition("=")` → `("a=b","=","c")` |
# | `rsplit(sep, maxsplit)` | Splits from right | `"a,b,c".rsplit(",",1)` → `["a,b","c"]` |
# | `rstrip(chars)` | Removes trailing chars | `"hi---".rstrip("-")` → `"hi"` |
# | `split(sep, maxsplit)` | Splits into list | `"a,b,c".split(",")` → `["a","b","c"]` |
# | `splitlines()` | Splits at line breaks | `"a\nb".splitlines()` → `["a","b"]` |
# | `startswith(prefix)` | Checks start of string | `"hello".startswith("he")` → `True` |
# | `strip(chars)` | Removes leading & trailing chars | `"--hi--".strip("-")` → `"hi"` |
# | `swapcase()` | Swaps case | `"Hello".swapcase()` → `"hELLO"` |
# | `title()` | Title-cases string | `"hello world".title()` → `"Hello World"` |
# | `translate(table)` | Maps characters using table | `"abc".translate(str.maketrans("a","x"))` → `"xbc"` |
# | `upper()` | Converts to uppercase | `"hello".upper()` → `"HELLO"` |
# | `zfill(width)` | Pads with zeros on the left | `"7".zfill(3)` → `"007"` |

# %% [markdown]
# #### The Python help() and dir() Function
#
# **The Struggle**: There are so many inbuilt methods available for each datatype. It will be hard to remember to all those. But its imperative to know what ability exists but not to mug it up. Once you start using them and you will automatically remember also.
#
# **The Concept**: You can use builtin `help` function which looks inside that object, retrieves the documentation stored within it, and prints it directly to your console without using internet. Similarly you can also use builtin `dir` function to retrieve all available methods.

# %%
# Pass the datatye or object to help
help(str)

# %%
help(23)

# %%
help(23.23)

# %%
# Pass the datatye or object to dir
dir(str)

# %%
# You can also pass value to dir
dir("cat")

# %%
dir(23)

# %%
dir(23.23)

# %% [markdown]
# ---
# ## 🗿 Topic 4: Immutability (The Statue Rule)
# This is a fancy computer science word.
# **Immutable** means "Cannot be changed."
#
# Once you create a string, you cannot change *part* of it. You have to create a *new* string.

# %%
my_text = "Cat"

# ❌ This will CRASH if you uncomment it
# my_text[0] = "B"  # You cannot change 'C' to 'B' directly.

# ✅ The Correct Way: Make a new variable
my_text = "B" + my_text[1:]
print(my_text) # Bat

# %% [markdown]
# #### Why Immutability Matters
#
# **Question**: "Why can't I just change the letter?"
#
# **Answer**: "Imagine a String is a carved stone tablet. You can't erase one letter. You have to carve a brand new tablet. Lists (which we learn tomorrow) are like whiteboards—you can erase and change them."

# %% [markdown]
# ---
# ## 🏋️ Day 8 Activities: Text Processing
#
# ### Level 1: The Initials Extractor 🆔
# 1. Ask the user for their `first_name`.
# 2. Ask for their `last_name`.
# 3. Print their initials. (Example: "Tony Stark" -> "T.S.")

# %%
# Write your code here for Level 1 Code

# %% [markdown]
# ### Level 2: The Slicer 🍕
# Variable: `sentence = "Python is amazing"`
# 1. Use slicing to extract just the word `"is"`.
# 2. Use slicing to extract `"amazing"`.
# 3. Print them.

# %%
# Write your code here for Level 2 Code

# %% [markdown]
# ### Level 3: The Censor Machine 🤬
# 1. Ask the user for a sentence.
# 2. If the sentence contains the word "math" (it's a scary word!), replace it with "****".
# 3. Print the cleaned sentence.
# *Hint: Use `.replace()`*

# %%
# Write your code here for Level 3 Code

# %% [markdown]
# ### Level 4: The Palindrome Checker 🔄
# A palindrome is a word that reads the same backward and forward (e.g., "racecar", "madam").
# 1. Ask user for a word.
# 2. Check if `word == word[::-1]`.
# 3. Print "Is Palindrome: True/False".

# %%
# Write your code here for Level 4 Code

# %% [markdown]
# ### Level 5: The Email Parser (Data Cleaning) 📧
# This is a real-world task!
# Input: A messy email like `"  USER@Example.com  "`
# 1. Remove the extra spaces.
# 2. Convert everything to lowercase.
# 3. Check if it ends with `.com`.
# 4. Print: "Cleaned Email: [email]"

# %%
# Write your code here for Level 5 Code
