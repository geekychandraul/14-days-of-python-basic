# %% [markdown]
# # Day 15: Phase 1 Capstone - The Python ATM 🏧
#
# ## 🏆 Milestone Reached!
# You have completed the **Phase 1: Fundamentals**.
# You now know:
# * Variables & Data Types
# * Logic (`if`, `else`)
# * Loops (`for`, `while`)
# * Data Structures (`Lists`, `Dicts`)
# * Functions & Scope
# * Error Handling
#
# Today, we don't learn anything new. **We build.**
#
# ---
#
# ## 🎯 The Project: Banking System
# We are going to build a text-based ATM machine.
#
# **Features Required:**
# 1.  **Login:** Ask the user for a PIN. If wrong 3 times, lock them out.
# 2.  **Menu:** Show options (Balance, Deposit, Withdraw, Exit).
# 3.  **Balance:** Show current money.
# 4.  **Deposit:** Add money to balance.
# 5.  **Withdraw:** Subtract money (but check if they have enough!).
# 6.  **Loop:** The menu should keep appearing until the user chooses "Exit".
#
# ---
#
# ## 🏗️ Step 1: Global Variables
# We need a place to store the money and the secret PIN.
# Since multiple functions need to access `balance`, we will use a Global Variable (Day 13).

# %% [markdown]
# - Create a secret
# - Create a place to store balance
# - You can also think of stroing transaction history for additional information.

# %%
# Write your code here

# %% [markdown]
# ## 🛠️ Step 2: Define the Functions
# We need "Machines" for each action.
#
# **Task 1:** Write `check_balance()`. It should print the balance.
#
# **Task 2:** Write `deposit(amount)`. It adds to balance and prints new total.
#
# **Task 3:** Write `withdraw(amount)`. It checks if you have enough money. If yes, subtract. If no, print "Insufficient Funds".

# %%
# Write your code here

# %% [markdown]
# ## 🔐 Step 3: The Login System
# We need a loop that gives the user 3 chances to enter the PIN.

# %%
# Write your code here

# %% [markdown]
# ## 🔄 Step 4: The Main Menu Loop
# This is the "Brain" of the application.
# It runs a `while True` loop that asks the user what they want to do. Give options like *check balance*, *Deposit*, *withdraw*, *view history* or to *exit*.

# %%
# Write your code here

# %% [markdown]
# ## 🧠 Challenge Mode (Homework)
# If you finished early, try adding these features:
# 1.  **Transfer:** Add option 6 to transfer money to another account (just simulate it).
# 2.  **Pin Change:** Allow user to change their PIN.
# 3.  **Bill Payment:** Pay an electricity bill (deducts from balance).
#
# **End of Phase 1.**
# Take a break. You earned it. ☕
