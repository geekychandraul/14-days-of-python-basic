# %% [markdown]
# # Getting started

# %% [markdown]
# # 🖥️ Command Line Confidence Guide
#
# Welcome!
# This guide is designed to help you **build confidence working at the command line**—a fundamental skill for any developer or data scientist.
#
# By the end of this guide, you'll be able to:
#
# * Navigate your file system like a pro
# * Create and delete directories and files
# * Move, copy, and rename things
# * And use powerful tools to work faster and smarter
#
# Don't worry if you're new to this—everything is explained step-by-step, with examples and exercises. Let's get started! 🚀

# %% [markdown]
# ## For Windows PC users
#
# Please see this guide:
#
# https://chatgpt.com/share/688529ad-535c-8010-949f-5156f0d3755e

# %% [markdown]
# ## For Mac users
#
# Please see this briefing:
#
# https://chatgpt.com/share/68852a48-2f1c-8010-9ccc-4f01eef552f4

# %% [markdown]
# ### 🐣 Common Beginner Mistakes at the Command Line
#
# Here are a few things that trip up almost everyone in the beginning — and that’s totally okay!
#
# #### 1. **Forgetting to `cd` into the right directory**
#
# Make sure you’re in the correct folder before running commands.
# 👉 Use `pwd` (Print Working Directory) to check where you are.
#
# #### 2. **Confusing `rm` and `mv`**
#
# * `rm` deletes files **permanently**
# * `mv` moves or renames them
#   ❗️There’s no undo button for `rm`, so use it carefully.
#
# #### 3. **Not using tab completion**
#
# You can press `Tab` while typing a filename or folder name — the terminal will auto-complete it for you.
# ✅ Saves time and avoids typos!
#
# #### 4. **Using the wrong slashes**
#
# * Use **forward slashes `/`** on Mac/Linux
# * Use **backslashes `\`** on Windows CMD
# * But on **PowerShell and Git Bash**, forward slashes often work too.
#
# #### 5. **Mixing up file paths**
#
# Relative vs absolute paths can be confusing at first.
# 🧭 Tip: `.` means “current directory” and `..` means “one level up”.

# %% [markdown]
# 💡 **Tip:** Please do experiment to build your confidence.
#
# Tools like **ChatGPT, Claude, Gemini, DeepSeek**, and others are your friends!
# They’re great at explaining command-line commands in simple terms, with examples tailored just for you.
#
# Don’t hesitate to ask them *“What does this command do?”* or *“Explain this step-by-step.”*
# With a little curiosity and practice, the command line will quickly start to feel like second nature.
