# %% [markdown]
# # Git and Github

# %% [markdown]
# This guide is all about using source code control: Git and Github.
#
# By the end of this, you should be confident with every day code control processes, including fetching the latest code and submitting a PR to merge your own changes.

# %% [markdown]
# ## 🧰 Getting Started with Git & GitHub
#
# New to Git or GitHub? No problem—we’ve got you covered! Whether you’re on a **PC or Mac**, this guide will help you understand the basics and get started with confidence.
#
# 🔗 **Start Here:**
# [👉 What is Git and GitHub? (Beginner-Friendly Guide)](https://chatgpt.com/canvas/shared/695be2bdf8908191bc2e81680ba9ea13)
#
# This quick explainer covers:
#
# * What Git is and why it's useful 🔄
# * What GitHub does and how it helps you collaborate 🌐
# * How to use them on your local machine 🧑‍💻
#
# > 💬 **Fun Fact:** Git was created by Linus Torvalds—the same person who created Linux!
#
# Take a few minutes to go through it—it’ll make the rest of the course much smoother, especially when you’re contributing your own awesome work!

# %% [markdown]
# ## 🔄 Stay Up-to-Date With the Latest Content!
#
# I’m always adding new examples, bonus exercises, and fresh materials to make this course even better for you. 🚀
#
# To make sure you’re not missing out, here’s how you can **pull in the latest updates** from the course repository.
#
# ### ⚡ The Easy Way (Quick Sync)
#
# If you’re not too worried about version control details and just want the latest updates fast:
#
# ```bash
# git pull origin main
# ```
#
# > 📌 This works best if you haven’t made major changes to your local files.
#
# ---
#
# ### 🧪 The Rigorous Way (If You've Made Changes)
#
# If you’ve made edits, added files, or personalized notebooks, use this method to safely bring in updates *without losing your work*:
#
# 1. **Commit your changes locally**
# 2. **Fetch the latest from origin**
# 3. **Rebase or merge carefully**
#    (or use a tool like GitHub Desktop to guide you)
#
# 📘 **Follow the instructions here:**
# [👉 Git Sync Tutorial (Full Walkthrough)](https://chatgpt.com/canvas/shared/695bb08ed0608191912e2b2ddaf1bc97)
#
# Need a hand? Feel free to reach out to me on LinkedIn. Git can be a bit quirky at times, but once you get the hang of it, it’s a superpower. 🧙‍♂️
#
# ---
#
# Keeping your materials fresh ensures you're always learning from the best and latest. Let’s keep building together! 🔧✨

# %% [markdown]
# ### 🌍 Share Your Work: Contribute to the Repo!
#
# Want to see your name listed as a contributor? 🌟 You absolutely should!
#
# If you've built something useful, made improvements, or just want to give back—**I’d be thrilled to include your contributions** in the course repo. It helps other students learn from your work, and you get public recognition right on GitHub!
#
# > 💬 **Bonus Perk:** Your GitHub profile will proudly display your contributions—great for your portfolio!
#
# ---
#
# ### 🛠️ How to Submit a Pull Request (PR)
#
# No worries if you're new to GitHub. Here’s a simple, step-by-step guide to help you submit a PR, even if it’s your first time:
#
# 📘 **Follow the instructions here:**
# [👉 How to Submit a Pull Request (Full Walkthrough)](https://chatgpt.com/canvas/shared/688346cceabc819186c9c3fcf7674616)
#
# It covers:
#
# * Forking the repo
# * Making changes in your copy
# * Creating a PR
# * Keeping things clean and conflict-free
#
# ---
#
# I can’t wait to see what you build. Let’s make this course better together—one contribution at a time! 🚀🙌

# %% [markdown]
# Here’s a polished and fun rewrite of your “Git pro” encouragement:
#
# ---
#
# ### 🧙‍♂️ Want to Become a Git Pro?
#
# If you’re curious about the magic behind Git and want to level up your skills, this guide is an absolute gem. 💎
#
# It’s clear, thorough, and even a bit entertaining. Honestly, if you read this, **you might know more than I do!**
#
# 📚 **Check it out:**
# [👉 BeeJ’s Guide to Git (The Deep Dive)](https://beej.us/guide/bggit/)
#
# > 🔍 **Pro Tip:** Bookmark this one—you’ll find yourself coming back to it when Git starts acting mysterious (and it will 😅).
#
# Whether you're a casual contributor or future open-source wizard, this guide will put powerful tools in your hands.
